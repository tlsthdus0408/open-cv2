# %%
from IPython.display import display, HTML
display(HTML("<style>div.container { width:100% !important; }</style>"))
# Out:
# <style>div.container { width:100% !important; }</style>

# %% [markdown]
# # 1.1 이미지 표현

# %% [markdown]
# ![lena.jpg](attachment:lena.jpg)

# %% [markdown]
# # 1.2 OpenCV

# %% [markdown]
# ## 1.2.1 OpecCV 라이브러리 호출

# %%
import cv2

# %% [markdown]
# ## 1.2.2 이미지 불러오기

# %%
lena_img=cv2.imread("./images/lena.jpg")
lena_img.shape
# Out:
# (512, 512, 3)

# %%
type(lena_img)
# Out:
# numpy.ndarray

# %%
lena_GRAYSCALE=cv2.imread("./images/lena.jpg",cv2.IMREAD_GRAYSCALE)
lena_GRAYSCALE=cv2.imread("./images/lena.jpg",cv2.IMREAD_UNCHANGED)
lena_img.shape
# Out:
# (512, 512)

# %% [markdown]
# # 1.2.3 이미지 출력하기

# %%
cv2.imshow("Lena.",lena_img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.imshow("Lena.",lena_GRAYSCALE)
cv2.imshow("Lena",c)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
cv2.imshow("Lena.",lena_GRAYSCALE)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
fname= "./images/lena.jpg"
colr=cv2.imread(fname, cv2.IMREAD_COLOR)
lena_GRAYSCALE=cv2.imread(fname,cv2.IMREAD_GRAYSCALE)
lena_IMSHOR=cv2.imread(fname,cv2.IMREAD_UNCHANGED)
cv2.imshow("colr",colr)
cv2.imshow("Graysclae",lena_GRAYSCALE)
cv2.imshow("UNCHANGED",lena_IMSHOR)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 1.2.4 이미지 저장하기

# %%
import cv2
img= cv2.imread("./images/lena.jpg",cv2.IMREAD_GRAYSCALE)
cv2.imwrite("lenagray.png",img)
# Out:
# True

# %%
split

# %% [markdown]
# # 1.2.5  matplotlib으로 이미지그리기

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img=cv2.imread("./images/lena.jpg", cv2.IMREAD_COLOR)
plt.imshow(img)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img=cv2.imread("./images/lena.jpg", cv2.IMREAD_COLOR)
b, g, r = cv2.split(img)
img2= cv2.merge([r,  g,  b])
plt.imshow(img2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 img=cv2.imread("./images/lena.jpg", cv2.IMREAD_COLOR)
# ----> 5 b, g, r = cv2.split(img)
#       6 img2= cv2.merge([r,  g,  b])
#       7 plt.imshow(img2)
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %% [markdown]
#  # 1.3 디지털 화상상 컬러

# %% [markdown]
# # 1.3.1 컬러공간 변환

# %%
flag=[flag for flag in dir(cv2) if flag.startswith("COLOR_")]
flag
# Out:
# ['COLOR_BAYER_BG2BGR',
#  'COLOR_BAYER_BG2BGRA',
#  'COLOR_BAYER_BG2BGR_EA',
#  'COLOR_BAYER_BG2BGR_VNG',
#  'COLOR_BAYER_BG2GRAY',
#  'COLOR_BAYER_BG2RGB',
#  'COLOR_BAYER_BG2RGBA',
#  'COLOR_BAYER_BG2RGB_EA',
#  'COLOR_BAYER_BG2RGB_VNG',
#  'COLOR_BAYER_BGGR2BGR',
#  'COLOR_BAYER_BGGR2BGRA',
#  'COLOR_BAYER_BGGR2BGR_EA',
#  'COLOR_BAYER_BGGR2BGR_VNG',
#  'COLOR_BAYER_BGGR2GRAY',
#  'COLOR_BAYER_BGGR2RGB',
#  'COLOR_BAYER_BGGR2RGBA',
#  'COLOR_BAYER_BGGR2RGB_EA',
#  'COLOR_BAYER_BGGR2RGB_VNG',
#  'COLOR_BAYER_GB2BGR',
#  'COLOR_BAYER_GB2BGRA',
#  'COLOR_BAYER_GB2BGR_EA',
#  'COLOR_BAYER_GB2BGR_VNG',
#  'COLOR_BAYER_GB2GRAY',
#  'COLOR_BAYER_GB2RGB',
#  'COLOR_BAYER_GB2RGBA',
#  'COLOR_BAYER_GB2RGB_EA',
#  'COLOR_BAYER_GB2RGB_VNG',
#  'COLOR_BAYER_GBRG2BGR',
#  'COLOR_BAYER_GBRG2BGRA',
#  'COLOR_BAYER_GBRG2BGR_EA',
#  'COLOR_BAYER_GBRG2BGR_VNG',
#  'COLOR_BAYER_GBRG2GRAY',
#  'COLOR_BAYER_GBRG2RGB',
#  'COLOR_BAYER_GBRG2RGBA',
#  'COLOR_BAYER_GBRG2RGB_EA',
# ...

# %%
lean_img= cv2.imread("./images/lena.jpg", cv2.IMREAD_COLOR)
B, G, R= lena_img[0][0]
print("컬러 화소:", lean_img[0][0])
print('B화소',B)
print('B화소',G)
print('B화소',R)
lean_gray=cv2.imread("./images/lena.jpg", cv2.IMREAD_GRAYSCALE)
print("그레이 스케일 화소",lean_gray[0][0])
# Out:
# 컬러 화소: [127 136 226]
# B화소 127
# B화소 136
# B화소 226
# 그레이 스케일 화소 162

# %% [markdown]
# # 1.4 동영상처리하기

# %% [markdown]
#  ## 1.4.1동영상 일기

# %%
import cv2
cap= cv2.VideoCapture("./images/Puppies-HD.mp4")
if cap.isOpened():
    print(cap.get(cv2.CAP_PROP_FPS))
    delay= int(100/cap.get(cv2.CAP_PROP_FPS))  
    while True:
        ret, img= cap. read()
        if ret:
                cv2.imshow("Movie",img)
                if cv2.waitKey(delay) & 0xFF == 27:
                    print("ESC key Pressed")
                    break
        else:
                print('No Frame')
                print(ret,img)
                    
else:
    print("File Not Opend")
cap.release()
cv2.destroyAllWindows()
# Out:
# 29.97002997002997
# ESC key Pressed

# %% [markdown]
# ## 1.4.2 카메라 영상 읽기

# %%
import cv2
cap= cv2.VideoCapture(0)
if cap.isOpened():
    print(cap.get(cv2.CAP_PROP_FPS))
    delay= int(100/cap.get(cv2.CAP_PROP_FPS))  
    while True:
        ret, img= cap. read()
        if ret:
                cv2.imshow("Movie",cv2.cvtColor(img,cv2.COLOR_BGR2GRAY))
                if cv2.waitKey(delay) & 0xFF == 27:
                    print("ESC key Pressed")
                    break
        else:
                print('No Frame')
                print(ret,img)
                    
else:
    print("Not Opend")
cap.release()
cv2.destroyAllWindows()
# Out:
# 30.0

# %%
import cv2
cap= cv2.VideoCapture(0)
if cap.isOpened():
    print(cap.get(cv2.CAP_PROP_FPS))
    delay= int(100/cap.get(cv2.CAP_PROP_FPS))  
    while True:
        ret, img= cap. read()
        if ret:
                cv2.imshow("Movie",img)
                if cv2.waitKey(delay) & 0xFF == 27:
                    print("ESC key Pressed")
                    break
        else:
                print('No Frame')
                print(ret,img)
                    
else:
    print("Not Opend")
cap.release()
cv2.destroyAllWindows()
# Out:
# 30.0
# ESC key Pressed

# %% [markdown]
# ## 1.4.3 동영상속성

# %%
import cv2
cap= cv2.VideoCapture(0)
print('번경전')
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
print("넓이 :",cv2.CAP_PROP_FRAME_WIDTH)
print("높이 :",cv2.CAP_PROP_FRAME_HEIGHT)
cap.set(cv2.CAP_PROP_FRAME_WIDTH,320)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT,320)
if cap.isOpened():
    print(cap.get(cv2.CAP_PROP_FPS))
    delay= int(100/cap.get(cv2.CAP_PROP_FPS))  
    while True:
        ret, img= cap. read()
        if ret:
                cv2.imshow("Movie",img)
                if cv2.waitKey(delay) & 0xFF == 27:
                    print("ESC key Pressed")
                    break
        else:
                print('No Frame')
                print(ret,img)
                    
else:
    print("Not Opend")
cap.release()
cv2.destroyAllWindows()
cap.release()
cv2.destroyAllWindows()
# Out:
# 번경전
# 넓이 : 3
# 높이 : 4
# 30.0
# ESC key Pressed

# %%
import cv2
cap = cv2.VideoCapture(0)
print("Before")
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print("넓이 :" , cv2.CAP_PROP_FRAME_WIDTH)
print("높이 :" , cv2.CAP_PROP_FRAME_HEIGHT)
cap.set(cv2.CAP_PROP_FRAME_WIDTH,1920)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT,1080)
print("After")
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
print("넓이 :" , cv2.CAP_PROP_FRAME_WIDTH)
print("높이 :" , cv2.CAP_PROP_FRAME_HEIGHT)
if cap.isOpened():
    delay = int(2000/ cap.get(cv2.CAP_PROP_FPS))
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow("Movie",img)
            if cv2.waitKey(30) & 0xFF == 27 :
                print("ESC Key pressed")
                break
        else:
            print("No Frame")
            print(ret, img)
            break
else:
    print("Camera not opened")
cap.release()
cv2.destroyAllWindows()
# Out:
# Before
# 넓이 : 3
# 높이 : 4
# After
# 넓이 : 3
# 높이 : 4
# ESC Key pressed

# %% [markdown]
# # 1.4.4 동영상 프레임저장하기

# %%
import cv2
import numpy as np
from datetime import datetime


def mouseHandler(event,x,y,flag,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(event,x,y)
        print(datetime.today())
        filename=str(datetime.today().microsecond)+".jpg"
        cv2.imwrite(filename,img)
cv2.namedWindow("Movie")
cv2.setMouseCallback("Movie",mouseHandler)
cap=cv2.VideoCapture("./images/Puppies-HD.mp4")
img=None
if cap.isOpened:
    print(cap.get(cv2.CAP_PROP_FPS))
    delay= int(100/cap.get(cv2.CAP_PROP_FPS))  
    while True:
        ret, img= cap. read()
        if ret:
                cv2.imshow("Movie",img)
                if cv2.waitKey(delay) & 0xFF == 27:
                    print("ESC key Pressed")
                    break
        else:
                print('No Frame')
                print(ret,img)  
else:
    print("File Not opend")
cap.release()
cv2.destroyAllWindows()
# Out:
# 29.97002997002997
# 1 490 202
# 2022-09-26 15:12:19.982289
# 1 762 230
# 2022-09-26 15:12:21.431813
# 1 837 456
# 2022-09-26 15:12:21.985790
# 1 687 437
# 2022-09-26 15:12:22.143061
# 1 686 279
# 2022-09-26 15:12:22.411001
# ESC key Pressed

# %%
import cv2
cap=cv2.VideoCapture("./images/Puppies-HD.mp4")
img=None
if cap.isOpened:
    fourcc= cv2.VideoWriter_fourcc(*"DIVX")#DLVX,XULD,FMP4,X246,MJPG:코덱
    width=cap.get(cv2.CAP_PROP_FRAME_WIDTH)
    heigt=cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
    size=(int(width),int(heigt))
    fps=cap.get(cv2.CAP_PROP_FPS)
    out =cv2.VideoWriter("video.avi",fourcc,fps,size)
    print(cap.get(cv2.CAP_PROP_FPS))
    delay= int(100/cap.get(cv2.CAP_PROP_FPS)) 
    print(width,heigt,size,fps,delay)
    while True:
        ret, img=cap.read()
        if ret:
            grey=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
            cv2.imshow("Movie",grey)
            out.write(cv2.cvtColor(grey,cv2.COLOR_GRAY2BGR))
            if cv2.waitKey(delay)& 0xFF == 27: 
                print("원도우 종료")
            break
        else:
            print('No Frame')
            print(ret,img)
            break   
else:
    print("비디오 안열림")
cap.release()
# Out:
# 29.97002997002997
# 1280.0 720.0 (1280, 720) 29.97002997002997 3

# %% [markdown]
# # 1.5 이벤트 처리하기

# %% [markdown]
# ## 1.5.1 마우스 이벤트

# %%
import cv2
import numpy as np
def draw_circle(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        if flags & cv2.EVENT_FLAG_CTRLKEY:
            cv2.rectangle(img, (x,y), (x+20, y+20), (0,0,255), -1)
        else:
            cv2.rectangle(img, (x,y), (x+20, y+20), (0,255,0), 2)
    elif event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img, (x,y), 10, (255,0,0), 2)
    elif event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img, (x,y), 20, (255,0,0), -1)
img = np.full((512,512,3), 255, dtype=np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)
while(1):
    cv2.imshow('image',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# ## 1.5.2 키보드

# %%
import cv2
import numpy as np
image = np.full((100, 100, 3), 255, np.uint8)
while(1):
    cv2.imshow("Key test", image)
    key = cv2.waitKey(0)
    print(f'Code: {key}, Char: {chr(key)}')
    if key & 0xFF == 27:
        break
cv2.destroyAllWindows()
# Out:
# Code: 27, Char:

# %% [markdown]
# ## 1.5.3 트랙바 이용하기

# %%
import cv2
import numpy as np
def nothing(x):
    pass
img = np.zeros((200,500,3), np.uint8)
cv2.namedWindow('image')
cv2.createTrackbar('Red', 'image', 0, 255, nothing)
cv2.createTrackbar('Green', 'image', 0, 255, nothing)
cv2.createTrackbar('Blue', 'image', 0, 255, nothing)
cv2.createTrackbar('0 or 1', 'image', 0, 1, nothing)
while(1):
    cv2.imshow('image', img)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
    r = cv2.getTrackbarPos('Red', 'image')
    g = cv2.getTrackbarPos('Green', 'image')
    b = cv2.getTrackbarPos('Blue', 'image')
    s = cv2.getTrackbarPos('0 or 1', 'image')
    if s == 0:
        img[:] = 0
    else:
        img[:] = [b,g,r]
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
img = np.zeros((200,500,3), np.uint8)
cv2.namedWindow('image')
def set_background(x):
    global img
    r = cv2.getTrackbarPos('Red', 'image')
    g = cv2.getTrackbarPos('Green', 'image')
    b = cv2.getTrackbarPos('Blue', 'image')
    s = cv2.getTrackbarPos('0 or 1', 'image')
    if s == 0:
        img[:] = 0
    else:
        img[:] = [b,g,r]
cv2.createTrackbar('Red', 'image', 0, 255, set_background)
cv2.createTrackbar('Green', 'image', 0, 255, set_background)
cv2.createTrackbar('Blue', 'image', 0, 255, set_background)
cv2.createTrackbar('0 or 1', 'image', 0, 1, set_background)
while(1):
    cv2.imshow('image', img)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
        break
cv2.destroyAllWindows()
